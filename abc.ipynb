# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/test/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/test/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.4.2)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/test/Downloads/ex.csv')

# %%
df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(16)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (2391, 5)

# %%
df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l=[]
for i in df['User-Rating']:
  l.append(i[1:3])
l
# Out:
# ['.8',
#  '.0',
#  '.7',
#  '.1',
#  '.2',
#  '.1',
#  '.2',
#  '.5',
#  '.2',
#  '.6',
#  '.8',
#  '.4',
#  '.1',
#  '.2',
#  '.0',
#  '.7',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.2',
#  '.2',
#  '.5',
#  '.6',
#  '.1',
#  '.0',
#  '.0',
#  '.2',
#  '.5',
#  '.4',
#  '.7',
#  '.3',
#  '.3',
#  '.5',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.4',
#  '.4',
#  '.8',
#  '.2',
#  '.2',
#  '.6',
#  '.6',
#  '.0',
#  '.1',
#  '.5',
#  '.5',
#  '.5',
#  '.7',
#  '.9',
#  '.6',
#  '.5',
#  '.1',
#  '.7',
#  '.6',
#  '.3',
#  '.7',
#  '.9',
#  '.0',
#  '.0',
#  '.3',
#  '.3',
#  '.1',
#  '.0',
#  '.7',
#  '.2',
#  '.1',
#  '.0',
#  '.9',
#  '.5',
#  '.5',
#  '.7',
#  '.0',
#  '.1',
#  '.1',
#  '.5',
#  '.1',
#  '.6',
#  '.4',
#  '.0',
#  '.0',
#  '.6',
#  '.3',
#  '.0',
#  '.2',
#  '.3',
#  '.1',
#  '.6',
#  '.5',
#  '.5',
#  '.0',
#  '.4',
#  '.2',
#  '.6',
#  '.3',
#  '.7',
#  '.2',
#  '.3',
#  '.7',
#  '.0',
#  '.5',
#  '.4',
#  '.0',
#  '.2',
#  '.0',
#  '.4',
#  '.4',
#  '.1',
#  '.3',
#  '.2',
#  '.1',
#  '.0',
#  '.8',
#  '.9',
#  '.8',
#  '.9',
#  '.2',
#  '.7',
#  '.2',
#  '.4',
#  '.0',
#  '.9',
#  '.9',
#  '.7',
#  '.9',
#  '.6',
#  '.5',
#  '.7',
#  '.4',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.3',
#  '.9',
#  '.7',
#  '.1',
#  '.6',
#  '.4',
#  '.6',
#  '.6',
#  '.1',
#  '.2',
#  '.6',
#  '.6',
#  '.8',
#  '.7',
#  '.4',
#  '.0',
#  '.1',
#  '.6',
#  '.3',
#  '.4',
#  '.2',
#  '.5',
#  '.6',
#  '.9',
#  '.4',
#  '.7',
#  '.4',
#  '.4',
#  '.5',
#  '.3',
#  '.1',
#  '.5',
#  '.4',
#  '.6',
#  '.4',
#  '.3',
#  '.1',
#  '.2',
#  '.0',
#  '.2',
#  '.7',
#  '.5',
#  '.7',
#  '.3',
#  '.3',
#  '.7',
#  '.0',
#  '.2',
#  '.2',
#  '.8',
#  '.1',
#  '.3',
#  '.2',
#  '.0',
#  '.2',
#  '.5',
#  '.6',
#  '.3',
#  '.7',
#  '.5',
#  '.9',
#  '.6',
#  '.7',
#  '.4',
#  '.2',
#  '.2',
#  '.1',
#  '.1',
#  '.7',
#  '.9',
#  '.4',
#  '.4',
#  '.0',
#  '.1',
#  '.4',
#  '.6',
#  '.3',
#  '.5',
#  '.5',
#  '.2',
#  '.6',
#  '.9',
#  '.6',
#  '.4',
#  '.4',
#  '.6',
#  '.6',
#  '.9',
#  '.6',
#  '.2',
#  '.7',
#  '.9',
#  '.7',
#  '.6',
#  '.2',
#  '.2',
#  '.2',
#  '.4',
#  '.0',
#  '.4',
#  '.7',
#  '.8',
#  '.6',
#  '.4',
#  '.9',
#  '.4',
#  '.0',
#  '.5',
#  '.5',
#  '.3',
#  '.7',
#  '.0',
#  '.2',
#  '.4',
#  '.1',
#  '.8',
#  '.1',
#  '.2',
#  '.2',
#  '.4',
#  '.0',
#  '.7',
#  '.4',
#  '.1',
#  '.8',
#  '.1',
#  '.1',
#  '.7',
#  '.7',
#  '.4',
#  '.5',
#  '.8',
#  '.9',
#  '.3',
#  '.5',
#  '.3',
#  '.2',
#  '.5',
#  '.9',
#  '.1',
#  '.3',
#  '.4',
#  '.3',
#  '.6',
#  '.8',
#  '.6',
#  '.1',
#  '.8',
#  '.8',
#  '.4',
#  '.4',
#  '.4',
#  '.1',
#  '.0',
#  '.5',
#  '.5',
#  '.3',
#  '.5',
#  '.9',
#  '.0',
#  '.6',
#  '.4',
#  '.5',
#  '.0',
#  '.5',
#  '.5',
#  '.8',
#  '.4',
#  '.3',
#  '.4',
#  '.1',
#  '.6',
#  '.7',
#  '.8',
#  '.1',
#  '.1',
#  '.1',
#  '.0',
#  '.3',
#  '.7',
#  '.2',
#  '.3',
#  '.3',
#  '.4',
#  '.0',
#  '.3',
#  '.9',
#  '.0',
#  '.4',
#  '.1',
#  '.4',
#  '.3',
#  '.6',
#  '.1',
#  '.0',
#  '.9',
#  '.5',
#  '.2',
#  '.2',
#  '.2',
#  '.4',
#  '.3',
#  '.4',
#  '.3',
#  '.3',
#  '.1',
#  '.3',
#  '.2',
#  '.2',
#  '.6',
#  '.4',
#  '.3',
#  '.1',
#  '.3',
#  '.6',
#  '.1',
#  '.8',
#  '.8',
#  '.1',
#  '.3',
#  '.5',
#  '.3',
#  '.8',
#  '.8',
#  '.2',
#  '.7',
#  '.4',
#  '.3',
#  '.1',
#  '.7',
#  '.6',
#  '.1',
#  '.9',
#  '.0',
#  '.2',
#  '.1',
#  '.1',
#  '.1',
#  '.1',
#  '.1',
#  '.1',
#  '.8',
#  '.8',
#  '.4',
#  '.7',
#  '.4',
#  '.4',
#  '.3',
#  '.1',
#  '.7',
#  '.9',
#  '.3',
#  '.4',
#  '.6',
#  '.4',
#  '.7',
#  '.0',
#  '.1',
#  '.1',
#  '.1',
#  '.4',
#  '.4',
#  '.5',
#  '.2',
#  '.3',
#  '.9',
#  '.4',
#  '.0',
#  '.5',
#  '.7',
#  '.2',
#  '.7',
#  '.0',
#  '.4',
#  '.2',
#  '.5',
#  '.7',
#  '.2',
#  '.4',
#  '.9',
#  '.2',
#  '.9',
#  '.6',
#  '.6',
#  '.7',
#  '.4',
#  '.3',
#  '.5',
#  '.3',
#  '.2',
#  '.8',
#  '.9',
#  '.3',
#  '.9',
#  '.4',
#  '.4',
#  '.2',
#  '.2',
#  '.0',
#  '.3',
#  '.9',
#  '.6',
#  '.2',
#  '.9',
#  '.6',
#  '.2',
#  '.2',
#  '.5',
#  '.3',
#  '.6',
#  '.6',
#  '.4',
#  '.1',
#  '.2',
#  '.8',
#  '.1',
#  '.2',
#  '.4',
#  '.6',
#  '.2',
#  '.5',
#  '.4',
#  '.3',
#  '.9',
#  '.2',
#  '.1',
#  '.2',
#  '.1',
#  '.5',
#  '.4',
#  '.8',
#  '.3',
#  '.4',
#  '.0',
#  '.7',
#  '.7',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.2',
#  '.2',
#  '.8',
#  '.8',
#  '.4',
#  '.7',
#  '.0',
#  '.4',
#  '.7',
#  '.4',
#  '.7',
#  '.5',
#  '.7',
#  '.3',
#  '.0',
#  '.0',
#  '.2',
#  '.6',
#  '.6',
#  '.1',
#  '.3',
#  '.9',
#  '.7',
#  '.3',
#  '.0',
#  '.8',
#  '.0',
#  '.3',
#  '.3',
#  '.3',
#  '.2',
#  '.2',
#  '.0',
#  '.4',
#  '.9',
#  '.0',
#  '.1',
#  '.1',
#  '.9',
#  '.4',
#  '.7',
#  '.5',
#  '.2',
#  '.4',
#  '.4',
#  '.1',
#  '.2',
#  '.5',
#  '.8',
#  '.7',
#  '.0',
#  '.2',
#  '.7',
#  '.6',
#  '.3',
#  '.0',
#  '.4',
#  '.6',
#  '.8',
#  '.0',
#  '.1',
#  '.3',
#  '.6',
#  '.0',
#  '.9',
#  '.4',
#  '.5',
#  '.9',
#  '.9',
#  '.1',
#  '.9',
#  '.8',
#  '.4',
#  '.2',
#  '.4',
#  '.9',
#  '.6',
#  '.1',
#  '.4',
#  '.5',
#  '.2',
#  '.7',
#  '.5',
#  '.2',
#  '.7',
#  '.4',
#  '.3',
#  '.5',
#  '.4',
#  '.1',
#  '.6',
#  '.5',
#  '.4',
#  '.1',
#  '.2',
#  '.6',
#  '.7',
#  '.9',
#  '.7',
#  '.7',
#  '.1',
#  '.2',
#  '.9',
#  '.9',
#  '.6',
#  '.0',
#  '.3',
#  '.6',
#  '.3',
#  '.3',
#  '.3',
#  '.5',
#  '.9',
#  '.8',
#  '.8',
#  '.6',
#  '.2',
#  '.7',
#  '.6',
#  '.7',
#  '.2',
#  '.2',
#  '.2',
#  '.3',
#  '.3',
#  '.5',
#  '.5',
#  '.9',
#  '.1',
#  '.7',
#  '.6',
#  '.3',
#  '.6',
#  '.7',
#  '.7',
#  '.9',
#  '.2',
#  '.5',
#  '.3',
#  '.3',
#  '.4',
#  '.3',
#  '.9',
#  '.2',
#  '.5',
#  '.6',
#  '.6',
#  '.7',
#  '.0',
#  '.4',
#  '.5',
#  '.2',
#  '.3',
#  '.8',
#  '.4',
#  '.5',
#  '.5',
#  '.1',
#  '.7',
#  '.4',
#  '.1',
#  '.9',
#  '.3',
#  '.1',
#  '.4',
#  '.5',
#  '.1',
#  '.6',
#  '.0',
#  '.5',
#  '.2',
#  '.3',
#  '.0',
#  '.6',
#  '.5',
#  '.4',
#  '.3',
#  '.2',
#  '.3',
#  '.5',
#  '.1',
#  '.2',
#  '.4',
#  '.5',
#  '.4',
#  '.6',
#  '.6',
#  '.2',
#  '.2',
#  '.2',
#  '.2',
#  '.9',
#  '.6',
#  '.3',
#  '.0',
#  '.6',
#  '.0',
#  '.2',
#  '.3',
#  '.4',
#  '.7',
#  '.6',
#  '.3',
#  '.9',
#  '.3',
#  '.5',
#  '.5',
#  '.0',
#  '.5',
#  '.2',
#  '.8',
#  '.6',
#  '.7',
#  '.3',
#  '.3',
#  '.4',
#  '.1',
#  '.3',
#  '.6',
#  '.6',
#  '.9',
#  '.5',
#  '.5',
#  '.8',
#  '.0',
#  '.6',
#  '.6',
#  '.6',
#  '.7',
#  '.5',
#  '.5',
#  '.6',
#  '.2',
#  '.1',
#  '.3',
#  '.6',
#  '.3',
#  '.5',
#  '.1',
#  '.2',
#  '.6',
#  '.6',
#  '.8',
#  '.8',
#  '.1',
#  '.0',
#  '.3',
#  '.1',
#  '.7',
#  '.0',
#  '.1',
#  '.2',
#  '.6',
#  '.4',
#  '.0',
#  '.7',
#  '.4',
#  '.3',
#  '.2',
#  '.1',
#  '.9',
#  '.3',
#  '.7',
#  '.4',
#  '.9',
#  '.3',
#  '.8',
#  '.0',
#  '.1',
#  '.3',
#  '.2',
#  '.5',
#  '.8',
#  '.7',
#  '.4',
#  '.2',
#  '.0',
#  '.9',
#  '.6',
#  '.1',
#  '.0',
#  '.6',
#  '.4',
#  '.3',
#  '.5',
#  '.6',
#  '.1',
#  '.3',
#  '.5',
#  '.2',
#  '.0',
#  '.4',
#  '.4',
#  '.5',
#  '.5',
#  '.5',
#  '.8',
#  '.3',
#  '.5',
#  '.1',
#  '.7',
#  '.1',
#  '.2',
#  '.3',
#  '.3',
#  '.7',
#  '.5',
#  '.6',
#  '.1',
#  '.0',
#  '.3',
#  '.1',
#  '.2',
#  '.6',
#  '.5',
#  '.4',
#  '.3',
#  '.9',
#  '.9',
#  '.3',
#  '.1',
#  '.9',
#  '.7',
#  '.8',
#  '.1',
#  '.1',
#  '.4',
#  '.4',
#  '.7',
#  '.1',
#  '.4',
#  '.3',
#  '.2',
#  '.6',
#  '.2',
#  '.3',
#  '.1',
#  '.9',
#  '.0',
#  '.2',
#  '.8',
#  '.2',
#  '.4',
#  '.4',
#  '.4',
#  '.2',
#  '.3',
#  '.3',
#  '.1',
#  '.4',
#  '.3',
#  '.4',
#  '.8',
#  '.0',
#  '.6',
#  '.3',
#  '.3',
#  '.4',
#  '.9',
#  '.4',
#  '.3',
#  '.3',
#  '.7',
#  '.5',
#  '.6',
#  '.4',
#  '.2',
#  '.3',
#  '.5',
#  '.3',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.2',
#  '.5',
#  '.7',
#  '.6',
#  '.2',
#  '.3',
#  '.3',
#  '.6',
#  '.0',
#  '.6',
#  '.7',
#  '.1',
#  '.1',
#  '.6',
#  '.5',
#  '.4',
#  '.2',
#  '.8',
#  '.5',
#  '.4',
#  '.0',
#  '.1',
#  '.4',
#  '.2',
#  '.4',
#  '.8',
#  '.5',
#  '.1',
#  '.4',
#  '.2',
#  '.0',
#  '.3',
#  '.6',
#  '.9',
#  '.5',
#  '.5',
#  '.6',
#  '.1',
#  '.1',
#  '.7',
#  '.7',
#  '.7',
#  '.3',
#  '.1',
#  '.2',
#  '.4',
#  '.3',
#  '.0',
#  '.2',
#  '.6',
#  '.7',
#  '.6',
#  '.6',
#  '.4',
#  '.3',
#  '.8',
#  '.0',
#  '.1',
#  '.0',
#  '.2',
#  '.8',
#  '.5',
#  '.8',
#  '.4',
#  '.4',
#  '.3',
#  '.2',
#  '.2',
#  '.2',
#  '.4',
#  '.4',
#  '.6',
#  '.6',
#  '.6',
#  '.2',
#  '.5',
#  '.4',
#  '.3',
#  '.5',
#  '.4',
#  '.5',
#  '.3',
#  '.2',
#  '.9',
#  '.4',
#  '.0',
#  '.3',
#  '.8',
#  '.3',
#  '.6',
#  '.0',
#  '.0',
#  '.4',
#  '.6',
#  '.4',
#  '.5',
#  '.8',
#  '.4',
#  '.3',
#  '.4',
#  '.2',
#  '.9',
#  '.2',
#  '.4',
#  '.6',
#  '.3',
#  '.6',
#  '.2',
#  '.1',
#  '.2',
#  '.5',
#  '.3',
#  '.5',
#  '.2',
#  '.4',
#  '.5',
#  '.3',
#  '.2',
#  '.6',
#  '.7',
#  '.1',
#  '.2',
#  '.6',
#  '.2',
#  '.2',
#  '.9',
#  '.6',
#  '.7',
#  '.3',
#  '.4',
#  '.2',
#  '.6',
#  '.5',
#  '.8',
#  '.5',
#  '.3',
#  '.8',
#  '.4',
#  '.9',
#  '.6',
#  '.2',
#  '.2',
#  '.3',
#  '.4',
#  '.2',
#  '.5',
#  '.3',
#  ...]

# %%
df['User-Rating']=l
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar, Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba          .8
# 1     BollywoodDanceRomantic                Luka Chuppi          .0
# 2             BollywoodDance                  Gully Boy          .7
# 3             BollywoodDance              Total Dhamaal          .1
# 4          BollywoodRomantic                     Simmba          .2
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural          .2
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai          .2
# 2417          BollywoodDance                      Lamhe          .5
# 2418          BollywoodDance          Shola Aur Shabnam          .5
# 2419          BollywoodDance          Shola Aur Shabnam          .6
#
# [2391 rows x 5 columns]

# %%
df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ' ,'')
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu,MikaSingh,NehaKakkar          BollywoodDance
# 1                         NehaKakkar,TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri,Shaan,SubhroGanguly          BollywoodDance
# 4     AseesKaur,RahatFatehAliKhan,TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar,SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
# [2391 rows x 5 columns]

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ' ,'')
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu,MikaSingh,NehaKakkar          BollywoodDance
# 1                         NehaKakkar,TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri,Shaan,SubhroGanguly          BollywoodDance
# 4     AseesKaur,RahatFatehAliKhan,TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar,SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
# [2391 rows x 5 columns]

# %%
df['tags']=df['Singer/Artists']+df['Genre']+df['Album/Movie']+df['User-Rating']
df['tags'][0]
# Out:
# 'KumarSanu,MikaSingh,NehaKakkarBollywoodDanceSimmba.8'

# %%
new_df=df[['Song-Name','tags']]

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
new_df
# Out:
# /var/folders/v5/fjnm3p1j2fxdgwf06wqbgyf00000gn/T/ipykernel_42817/2565169282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     kumarsanu,mikasingh,nehakakkarbollywooddancesi...
# 1     nehakakkar,tonykakkarbollywooddanceromanticluk...
# 2                  ranveersinghbollywooddancegullyboy.7
# 3     jyoticatangri,shaan,subhrogangulybollywooddanc...
# 4     aseeskaur,rahatfatehalikhan,tanishkbagchibolly...
# ...                                                 ...
# 2415                      mukeshbollywooddancesasural.2
# 2416  latamangeshkarbollywooddancejabpyarkisisehotah...
# 2417   latamangeshkar,sureshwadkarbollywooddancelamhe.5
# 2418          jagjitkaurbollywooddancesholaaurshabnam.5
# 2419          ashabhoslebollywooddancesholaaurshabnam.6
#
# [2391 rows x 2 columns]

# %%
 pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2000)

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 2000)

# %%
cv.get_feature_names_out()
# Out:
# array(['55', '7ekterasaath', '9211', ...,
#        'zubeengargbollywooddanceaashayein',
#        'zubeengargbollywooddancedummaarodum',
#        'zubeengargbollywooddanceiseeyou'], shape=(2000,), dtype=object)

# %%
#from sklearn.metrics.pairwise import cosine_similarity
#similarity = cosine_similarity(vectors)

# %%
#sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x:x[1])'''

# %%
#new_df.rename(columns={'Song-Name':'title'},inplace=True)

# %%
#def recommend(music):
  #music_index = new_df[new_df['title']==music].index[0]
  #distances = similarity[music_index]
  #music_list = sorted(list(enumerate(distances)),reverse=True, key=lambda x:x[1])[1:6]
  #for i in music_list:
    #print(new_df.iloc[i[0]].title)

# %%
#recommend('Ishq Risk')

# %%
#df.head(50)

# %%
#similarity = ...
#music_dict = ...

# %%
#pickle.dump(new_df, open('/Users/test/Desktop/Task2/similarities.pkl','wb'))
#import pickle

#pickle.dump(similarity, open('similarities.pkl','wb'))
#pickle.dump(music_dict, open('musicrec.pkl','wb'))

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

df = pd.read_csv("/Users/test/Downloads/ex.csv")

df['Singer/Artists'] = df['Singer/Artists'].fillna('')
df['Genre'] = df['Genre'].fillna('')
df['Album/Movie'] = df['Album/Movie'].fillna('')

df['tags'] = (
    df['Singer/Artists'] + " " +
    df['Genre'] + " " +
    df['Album/Movie']
)

df['tags'] = df['tags'].astype(str).str.lower()

new_df = df[['Song-Name', 'tags']].copy()
new_df.rename(columns={'Song-Name': 'title'}, inplace=True)

cv = CountVectorizer(max_features=2000, stop_words='english')
vectors = cv.fit_transform(new_df['tags']).toarray()

similarity = cosine_similarity(vectors)

pickle.dump(new_df, open('musicrec.pkl','wb'))
pickle.dump(similarity, open('similarities.pkl','wb'))

print("✅ Pickle files recreated successfully!")
# Out:
# ✅ Pickle files recreated successfully!

# %%
#pip install streamlit
